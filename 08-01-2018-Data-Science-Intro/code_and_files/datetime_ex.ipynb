# %%
import datetime

# %%
time = datetime.datetime.now()

# %%
def greeting(time):
    name = 'Jess'
    print('Hello {}, the time is {}'.format(name, time))

# %%
greeting(time=time)
# Out:
# Hello Jess, the time is 2018-08-01 19:21:21.153733
